# %% [markdown]
# # 01 - Data Pipeline
# Load sample fixture and form data for AC Milan.

# %%
import os, sys
sys.path.append(os.path.abspath('..'))

from src.data_ingestion import sample_upcoming_fixtures, sample_recent_form, compute_streak

fixtures = sample_upcoming_fixtures('AC Milan')
form = sample_recent_form('AC Milan')
streak = compute_streak(form)

print('Current streak:', streak)
fixtures
# Out:
# Current streak: 3
#        team     opponent       competition                   kickoff  \
# 0  AC Milan  Inter Milan           Serie A 2026-04-16 19:00:00-07:00
# 1  AC Milan     Juventus      Coppa Italia 2026-04-19 16:00:00-07:00
# 2  AC Milan       Napoli           Serie A 2026-04-22 18:00:00-07:00
# 3  AC Milan          PSG  Champions League 2026-04-26 17:00:00-07:00
#
#    is_derby  is_knockout  home
# 0         1            0     0
# 1         0            1     1
# 2         0            0     1
# 3         0            1     0

# %%
form
# Out:
#        team          match result  goals_for  goals_against  xg_for  \
# 0  AC Milan       vs Lazio      W          2              1     1.8
# 1  AC Milan        vs Roma      W          3              1     2.1
# 2  AC Milan    vs Atalanta      W          1              0     1.2
# 3  AC Milan  vs Fiorentina      D          1              1     1.0
# 4  AC Milan      vs Torino      L          0              1     0.7
#
#    xg_against
# 0         0.9
# 1         0.8
# 2         0.6
# 3         1.1
# 4         1.3
