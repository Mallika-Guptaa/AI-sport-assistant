# %% [markdown]
# # 05 - Match Prediction
# Train a simple ML model for win probability.

# %%
import os, sys
sys.path.append(os.path.abspath('..'))

from src.prediction_engine import generate_synthetic_training_data, train_predictor, predict_match_win_probability

train_df = generate_synthetic_training_data(n=600, seed=21)
artifacts = train_predictor(train_df)
print('Validation accuracy:', round(artifacts.accuracy, 3))

sample_match = {
    'home': 1,
    'team_form_points_last5': 11,
    'opp_form_points_last5': 7,
    'team_xg_last5': 1.7,
    'opp_xg_last5': 1.1,
    'is_knockout': 1,
}

p_win = predict_match_win_probability(artifacts.model, sample_match)
print('Predicted win probability:', round(p_win, 3))
# Out:
# Validation accuracy: 0.66
# Predicted win probability: 0.826
# /Users/mallikagupta/Documents/New project/.venv/lib/python3.13/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/mallikagupta/Documents/New project/.venv/lib/python3.13/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/mallikagupta/Documents/New project/.venv/lib/python3.13/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
